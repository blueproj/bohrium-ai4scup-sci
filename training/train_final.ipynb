# %% [markdown]
# ### 环境安装

# %%
# !pip install --no-index --find-links=file:/bohr/sci-pkgs-w6lh/v1/pkgs -r /bohr/sci-re-0lem/v1/pkgs_vllm.txt

# %%
# !pip install deepspeed

# %%
# !cp -r /bohr/train-code-x3qy/v1/train_code .

# %% [markdown]
# ### task1

# %%
# !cd train_code && bash train_zero2_task1_1.sh

# %%
# !cd train_code && bash train_zero2_task1_2.sh

# %%
# !cd train_code && bash train_zero2_task1_3.sh

# %% [markdown]
# ### task2

# %%
# !cd train_code && bash train_zero2_task2.sh

# %% [markdown]
# ### task3

# %%
# !cd train_code/task3_sft && bash finetune_lora_no_eval.sh

# %% [markdown]
# ### task5

# %%
# !cd train_code && bash train_zero2_task5.sh

# %% [markdown]
# ### task6

# %%
# !cd train_code/task6_sft && bash finetune_lora_no_eval.sh

# %% [markdown]
# ### task7

# %%
# !cd train_code && bash train_zero2_task7.sh
